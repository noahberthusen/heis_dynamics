# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import scipy.signal
import matplotlib
# %matplotlib inline

# %%
def func(x, a, b, c):
    return a * np.exp(-b * x) + c

def func2(x, a, b):
    return a * np.exp(-b * x)

def func3(x, a, b, c):
    return a + (b / 2**(x/c))

def fun(x, a, b, c):
    return a*np.exp(-b*(c**x))

# %%
# L=8
y = [0.7590718540880695, 0.5719211366047965, 0.44510673104760407, 0.3241760396769466, 0.2550839283040911, 0.20338644928503405, 0.16657267588874713, 0.13303684756303158, 0.09179578796168021, 0.06102443877810375, 0.032180786182541075, 0.021368967806325422, 0.010754411919488305, 0.0043950994366458995]
x = np.arange(len(y))

popt, pcov = curve_fit(fun, x, y)
print(popt)
predx = np.linspace(0, len(y)+2, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')
print(f'actual p* = 14')

plt.plot(x, y, 'b-', label='data')
plt.plot(predx, pred, 'r-')
plt.axhline(5e-3, color='k', linestyle='--')
plt.yscale('log')
plt.legend()

# %%
# L=9
y = [0.8487796466464832, 0.7246713564910872, 0.6212977022476487, 0.5601619345396789, 0.4708760688783845, 0.41385549557756507, 0.3608916901805358, 0.30257921928460585, 0.24985423332471882, 0.19539132415233107, 0.1679920211863423, 0.13669538443585097, 0.11212563368131197, 0.08873980822580929, 0.06822397613094205, 0.05092762634877268, 0.03898776643879624, 0.02921738040071047, 0.020098550656726288, 0.014498611773404769, 0.0071355138558909514, 0.0043125361783976635, 0.002548221151697283, 0.0011333996251954304, 0.0004074573587542485]

x = np.arange(len(y))

popt, pcov = curve_fit(fun, x, y)
print(popt)
predx = np.linspace(0, len(y)+10, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')
print(f'actual p* = 14')

plt.plot(x, y, 'b-', label='data')
plt.yscale('log')
plt.plot(predx, pred, 'r-', label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))
plt.axhline(5e-3, color='k', linestyle='--')
plt.legend()
# Out:
# [11.0468602   2.58499491  1.04952064]
# p* prediction = 22.573757375737575
# actual p* = 14
# C:\Users\nfber\anaconda3\envs\qc\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in exp
#   # This is added back by InteractiveShellApp.init_path()

# %%
# L=10
y = [0.8743803794511876, 0.7602827036510854, 0.6283331545866673, 0.5628693380619201, 0.4921650094542621, 0.4256666141075628, 0.38455154797254093, 0.33474153611510793, 0.30555276126916875, 0.2997335321936316, 0.28403853926060596, 0.32331078335113633, 0.2605064704572483, 0.2701202553798495, 0.25988398779544275, 0.23296151808521248, 0.21691028941228307, 0.18272598198029488, 0.18016026093971216, 0.14507519284391246, 0.14432891969153894, 0.13215513174156102, 0.11645455273223815, 0.10780069121860303, 0.08184172387280209, 0.07124292315053182, 0.06695249692045613, 0.06004606181960437, 0.05447963474429951, 0.05066997157910613, 0.035307219169577686, 0.03405049668035065, 0.024741642898890692, 0.021846105971423002, 0.017336086230235193, 0.012528126860723132, 0.01008166471798333, 0.008636011985746816, 0.007922392087377883, 0.005485597676916254]
x = np.arange(len(y))
y = scipy.signal.savgol_filter(y, 21, 1)

popt, pcov = curve_fit(fun, x, y)
print(popt)
predx = np.linspace(0, len(y)+10, 100)
pred = fun(predx, *popt)

# print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')
print(f'actual p* = 14')

plt.plot(x, y, 'b-', label='data')
plt.yscale('log')
plt.plot(predx, pred, 'r-', label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))
plt.axhline(5e-3, color='k', linestyle='--')
plt.legend()
# Out:
# [3.05957509 1.53207858 1.03438198]
# actual p* = 14
# C:\Users\nfber\anaconda3\envs\qc\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in exp
#   # This is added back by InteractiveShellApp.init_path()

# %%
# L=12
y = [0.9751112418210389, 0.9210955531824921, 0.8201313036697626, 0.6663207367089683, 0.5833245539523475, 0.6903652330160268, 0.6794280743460828, 0.6622884791941834, 0.5308469210345069, 0.48447960953220714, 0.46626401587971456, 0.7376492893890618, 0.7176225052287388, 0.4289809784266416, 0.6595318244874002, 0.6286823297384729, 0.6459200141628603, 0.6315901323989077, 0.610140206148684, 0.5998989172246494, 0.5674853918209991, 0.5577340646844129, 0.5379943600386332, 0.5245152615353144, 0.5272030871189091, 0.5084456076609083, 0.4872802571261001, 0.4824489862908722, 0.4579562491514846, 0.4405925614931723, 0.4327551216498321, 0.4223644954052357, 0.41956136682372724, 0.40133813301286836, 0.3748028788383003, 0.36652637391387766, 0.36743520238555527, 0.35078597821059787, 0.34215841044269046, 0.32215841044269046, 0.31082346760905977, 0.30215841044269046, 0.2987874664417134, 0.27930962249731506, 0.2858732561483256]
x = np.arange(len(y))+1
y = scipy.signal.savgol_filter(y, 41, 1)

popt, pcov = curve_fit(fun, x, y)
print(popt)
predx = np.linspace(0, len(y)+80, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')

plt.plot(x, y, 'b-', label='data')
plt.plot(predx, pred, 'r-')
plt.axhline(5e-3, color='k', linestyle='--')
plt.yscale('log')
plt.legend()
# Out:
# [2.09250204 0.98405314 1.01524511]
# p* prediction = 119.83698369836983

# %%
# L=11 zz
y = [0.9261151779099567, 0.8511945891384742, 0.7693913421191709, 0.7073966104074536, 0.6350478379136983, 0.5722619483297715, 0.5140257240775905, 0.46788426632209407, 0.4159054651627615, 0.37253946949386274, 0.34305439845434527, 0.28397825796210435, 0.2621012760382251, 0.2292239802230862, 0.2092687281810458, 0.1758191269051449, 0.15842184067966425, 0.14045944600811022, 0.11961690247603807, 0.09650567935767884, 0.08439628643918373, 0.07616674755108555, 0.06594632341955187, 0.05024206309546597, 0.0439167088314526, 0.03608847978753271, 0.030658143234543078]
x = np.arange(len(y))+1
y = scipy.signal.savgol_filter(y, 5, 1)


print(len(y))
popt, pcov = curve_fit(fun, x, y, p0=[10, 3, 1])
print(popt)
predx = np.linspace(0, len(y)+20, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')

plt.plot(x, y, 'b-', label='data')
plt.plot(predx, pred, 'r-')
plt.axhline(5e-3, color='k', linestyle='--')
plt.yscale('log')
plt.legend()
# Out:
# 27
# [20.53478293  3.01144323  1.02867543]
# p* prediction = 35.93039303930393

# %%
# L=12 zz
y = [0.9215268053214467, 0.8947150072594636, 0.756560547328556, 0.7481819851826412, 0.7020367617880663, 0.7443771570796638, 0.6951728971465105, 0.654915440307857, 0.6296107872964507, 0.5990934084181154, 0.5580417603538999, 0.538481361310186, 0.5121406786777314, 0.47318452352383866, 0.442809256001812, 0.4166217774796289, 0.40120029600185225, 0.37096456009185375, 0.3415075810431778, 0.3267508304132922, 0.31370237153318203, 0.2950986121749114, 0.2735931212022831, 0.2519625967292435]
x = np.arange(len(y))+1
y = scipy.signal.savgol_filter(y, 5, 1)


print(len(y))
popt, pcov = curve_fit(fun, x, y, p0=[10, 3, 1])
print(popt)
predx = np.linspace(0, len(y)+100, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')

plt.plot(x, y, 'b-', label='data')
plt.plot(predx, pred, 'r-')
plt.axhline(5e-3, color='k', linestyle='--')
plt.yscale('log')
plt.legend()
# Out:
# 24
# [6.38577003 1.92160206 1.02178893]
# p* prediction = 60.952095209520955
# ipykernel_launcher:11: RuntimeWarning: overflow encountered in exp

# %%
# L=11
y = [0.9523546025921042, 0.8555128016751308, 0.8063569452557587, 0.7261054889051939, 0.6978882496845253, 0.6834919785982947, 0.635797680284956, 0.6205954241998789, 0.5384254387354159, 0.5559438904383859, 0.5042318357190083, 0.5814076997947872, 0.5221411476862388, 0.4976713854300342, 0.4738036553177448, 0.4653931197929507, 0.4400977965809585, 0.4126562522758186, 0.3858833451864703, 0.34984039120869226, 0.33230623366677026, 0.33588471044822343, 0.3173069764439742, 0.2868568800355503, 0.27678989224888395, 0.24121697004244091, 0.2404776355519881, 0.2131823868564816, 0.21537698018374085, 0.1897678008110455, 0.18869844767280397, 0.1739360202170127, 0.16411085510701295, 0.15064124732492412, 0.14139546400083824]
x = np.arange(len(y))+1
yhat = scipy.signal.savgol_filter(y, 11, 1)

print(len(y))
popt, pcov = curve_fit(fun, x, yhat, maxfev=3000)
print(popt)
predx = np.linspace(0, len(y)+50, 10000)
pred = fun(predx, *popt)

print(f'p* prediction = {predx[np.argwhere(np.isclose(5e-3, pred, rtol=5e-3)).flatten()[0]]}')

plt.plot(x, y, 'b-', label='data')
plt.plot(predx, pred, 'r-')
plt.axhline(5e-3, color='k', linestyle='--')
plt.yscale('log')
plt.legend()
# Out:
# 35
# [24.11011663  3.27541194  1.01263423]
# p* prediction = 75.73407340734073

# %%
fig, ax = plt.subplots(1, 1, figsize=(5,3))

f10 = np.loadtxt('./other_results/8_pvstime/results_time_8_10.txt', delimiter=',')
f6 = np.loadtxt('./other_results/8_pvstime/results_time_8_6.txt', delimiter=',')
f14 = np.loadtxt('./other_results/8_pvstime/results_time_8_14.txt', delimiter=',')
f18 = np.loadtxt('./other_results/8_pvstime/results_time_8_18.txt', delimiter=',')
f2 = np.loadtxt('./other_results/8_pvstime/results_time_8_2.txt', delimiter=',')

color = matplotlib.cm.viridis
# c = np.arange(3, 3 + len(Ls))
# norm = matplotlib.colors.Normalize(vmin=c.min(), vmax=c.max())
# cmap = matplotlib.cm.ScalarMappable(norm=norm, cmap=color)
# cmap.set_array([])

ax.set_prop_cycle('color', [color(i) for i in np.linspace(0, 0.8, 5)])

ax.plot(f2[:,1], f2[:,0], '-', label='$p=2$', markersize=3)
ax.plot(f6[:,1], f6[:,0], '-', label='$p=6$', markersize=3)
ax.plot(f10[:,1], f10[:,0], '-', label='$p=10$', markersize=3)
ax.plot(f14[:,1], f14[:,0], '-', label='$p=14$', markersize=3)
ax.plot(f18[:,1], f18[:,0], '-', label='$p=18$', markersize=3)
plt.axhline(5e-3, color='k', linestyle='--')
ax.set_ylabel('$1-F$')
ax.set_xlabel('$Jt$')

plt.yscale('log')
# plt.xscale('log')
plt.legend()
plt.savefig('figures/t_vs_fidelity', dpi=300, transparent=False, bbox_inches='tight')
